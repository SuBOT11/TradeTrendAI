# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
file_path = '/mnt/d/dataStorage/UPNepseDataLake/historicNepseData/GLBSL_data/GLBSL.parquet'
df = pd.read_parquet(file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1007 non-null   object
#  1   Open    1007 non-null   float64
#  2   High    1007 non-null   float64
#  3   Low     1007 non-null   float64
#  4   Close   1007 non-null   float64
#  5   Volume  1007 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 47.3+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info
# Out:
# <bound method DataFrame.info of            Date    Open    High     Low   Close  Volume
# 0    2019-06-02  213.25  213.25  213.25  213.25    20.0
# 1    2019-06-03  223.18  223.18  223.18  223.18    10.0
# 2    2019-06-05  233.88  238.47  233.88  238.47    20.0
# 3    2019-06-07  249.93  249.93  249.93  249.93    10.0
# 4    2019-06-17  262.16  262.16  262.16  262.16    10.0
# ...         ...     ...     ...     ...     ...     ...
# 1002 2023-12-13  660.00  670.00  650.10  670.00   279.0
# 1003 2023-12-14  665.00  679.00  657.00  679.00   123.0
# 1004 2023-12-15  679.00  679.00  645.20  645.20   113.0
# 1005 2023-12-18  657.00  698.00  641.50  698.00   413.0
# 1006 2023-12-19  699.00  731.00  685.10  731.00   815.0
#
# [1007 rows x 6 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1007 non-null   datetime64[ns]
#  1   Open    1007 non-null   float64
#  2   High    1007 non-null   float64
#  3   Low     1007 non-null   float64
#  4   Close   1007 non-null   float64
#  5   Volume  1007 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 47.3 KB

# %%
df.plot(subplots=True,figsize=(10,12))

plt.title('attributes ')
plt.savefig('stocks.png')
plt.show()

# %%
df.drop(columns=['Change'],inplace=True)

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close  Volume
# 0 2019-06-02  213.25  213.25  213.25  213.25    20.0
# 1 2019-06-03  223.18  223.18  223.18  223.18    10.0
# 2 2019-06-05  233.88  238.47  233.88  238.47    20.0
# 3 2019-06-07  249.93  249.93  249.93  249.93    10.0
# 4 2019-06-17  262.16  262.16  262.16  262.16    10.0

# %%
df['Change']  = df.Close.div(df.Close.shift())

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close  Volume    Change
# 0 2019-06-02  213.25  213.25  213.25  213.25    20.0       NaN
# 1 2019-06-03  223.18  223.18  223.18  223.18    10.0  1.046565
# 2 2019-06-05  233.88  238.47  233.88  238.47    20.0  1.068510
# 3 2019-06-07  249.93  249.93  249.93  249.93    10.0  1.048056
# 4 2019-06-17  262.16  262.16  262.16  262.16    10.0  1.048934

# %%
df.sort_values(by='Change')
# Out:
#           Date    Open     High     Low    Close  Volume    Change
# 207 2020-07-21  815.90   815.90  749.29   749.29  1350.0  0.900199
# 189 2020-03-18  528.86   528.86  487.73   487.73   287.0  0.903957
# 39  2019-08-06  443.31   451.72  398.98   401.27  4423.0  0.906743
# 802 2023-01-13  951.80   951.80  882.00   882.00  2448.0  0.908155
# 208 2020-07-22  734.48   734.48  674.44   681.84  2192.0  0.909981
# ..         ...     ...      ...     ...      ...     ...       ...
# 331 2021-01-25  973.83  1050.32  973.83  1050.32  4142.0  1.099927
# 708 2022-08-09  942.31  1057.69  905.10  1057.69  3345.0  1.099996
# 206 2020-07-20  771.49   832.36  771.49   832.36   144.0  1.100016
# 219 2020-08-07  678.55   759.98  667.04   759.98   641.0  1.100017
# 0   2019-06-02  213.25   213.25  213.25   213.25    20.0       NaN
#
# [1007 rows x 7 columns]

# %%
df['Change'].plot(figsize=(20,8))
# Out:
# <Axes: >

# %%
df['Return'] = df.Change.sub(1).mul(100)
df['Return'].plot(figsize=(20,8))
# Out:
# <Axes: >

# %%
df
